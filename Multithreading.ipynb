# %% [markdown]
# # Multithreading

# %%
class circle:
    def run(self):
        for i in range(5):
            print("cirle")

class square:
    def run(self):
        for i in range(5):
            print("square")


t1=circle()
t2=square()

t1.run()
t2.run()
# Out:
# cirle
# cirle
# cirle
# cirle
# cirle
# square
# square
# square
# square
# square

# %%
from threading import *
#from threading import Thread

class circle(Thread):
    def run(self):
        for i in range(5):
            print("cirle")

class square(Thread):
    def run(self):
        for i in range(5):
            print("square")


t1=circle()
t2=square()

t1.run()
t2.run()
# Out:
# cirle
# cirle
# cirle
# cirle
# cirle
# square
# square
# square
# square
# square

# %%
class circle(Thread):   #inside thread class you have method called run 
    def run(self):
        for i in range(25):
            print("cirle")  

class square(Thread):
    def run(self):
        for i in range(25):
            print("square")


t1=circle()
t2=square()

t1.start() # internally it will call run
t2.start()
# Out:
# cirlesquare
# square
# square
# square
# square
#
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# squarecirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
#
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# cirle
# cirle
# cirle
# cirle
# cirle
# cirle
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square
# square

# %%
from time import sleep

class circle(Thread):
    def run(self):
        for i in range(20):
            print("cirle")  
            sleep(1)
            
class square(Thread):
    def run(self):
        for i in range(20):
            print("square")
            sleep(1)
            

t1=circle()
t2=square()

t1.start() # internally it will call run
t2.start()
# Out:
# cirlesquare
#
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# squarecirle
#
# cirlesquare
#
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# squarecirle
#
# cirle
# square
# cirlesquare
#
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# square
# cirle
# squarecirle
#
# cirlesquare
#
# cirlesquare
#
# cirlesquare
#
# cirlesquare
#
# squarecirle
#
# cirle
# square
# square
# cirle
# square
# cirle
# squarecirle
#
# cirle
# square
# cirle
# square
# squarecirle
#
# cirle
# square
# cirlesquare
#
# squarecirle
#
# square
# cirle
# square
# cirle
# squarecirle
#
# square
# cirle

# %%
from time import sleep

class circle(Thread):
    def run(self):
        for i in range(20):
            print("cirle")  
            sleep(1)
            
class square(Thread):
    def run(self):
        for i in range(20):
            print("square")
            sleep(1)
            

t1=circle()
t2=square()

t1.start() # internally it will call run
sleep(0.2)
t2.start()

print("Bye")
# Out:
# cirle
# squareBye
#
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square

# %%
from time import sleep

class circle(Thread):
    def run(self):
        for i in range(5):
            print("cirle")  
            sleep(1)
            
class square(Thread):
    def run(self):
        for i in range(5):
            print("square")
            sleep(1)
            

t1=circle()
t2=square()

t1.start() # internally it will call run
sleep(0.2)
t2.start()

t1.join() #join() function, which makes the main thread wait for the child to finish.
t2.join()

print("Bye")
# Out:
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# cirle
# square
# Bye
